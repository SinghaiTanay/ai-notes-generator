# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("groq:llama-3.1-8b-instant")

# %%
from pydantic import BaseModel, Field

class notes(BaseModel):
    topic: str = Field(description="Name of the topic")
    definition: str = Field(description="Definition of the topic")
    important_points: list[str] = Field(description="important points of the topic")
    advantages: list[str] = Field(description="advantage of the topic")
    disadvantages: list[str] = Field(description="disadvantage of the topic")
    exam_tip: str = Field(description="Exam tip")

# %%
str_model = model.with_structured_output(notes)

# %%
topic = input("Enter Topic Name:")

prompt = f"""
You are an expert teacher.

Explain {topic} in simple language for a B.Tech student.

Provide:
- Topic Name
- Definition
- 5 Important Points
- Advantages (if applicable)
- Disadvantages
- Exam Tip

Keep the explanation concise and exam-oriented.
"""


response = str_model.invoke(prompt)

# %%
response
# Out:
# notes(topic='Deadlock', definition='A deadlock is a situation in a multithreaded program where two or more threads are unable to proceed because each is waiting for the other to release a resource.', important_points=['Deadlock occurs when two or more threads are competing for shared resources.', 'Each thread is waiting for the other thread to release a resource.', 'Deadlock can occur in operating systems, databases, and other applications.', 'Deadlock can be avoided by using techniques such as locking ordering and deadlock detection.', 'Deadlock detection and recovery can be costly in terms of system resources and time.'], advantages=['Deadlock detection can help prevent system crashes and data loss.'], disadvantages=['Deadlock detection and recovery can be costly in terms of system resources and time.', 'Deadlock can cause system instability and performance issues.'], exam_tip='To avoid deadlock, always follow a consistent locking order and use techniques such as deadlock detection
# ...

# %%
print(f"Topic: {response.topic}")
print(f"\nDefinition:\n{response.definition}")

print("\nImportant Points:")
for point in response.important_points:
    print(f"- {point}")

print("\nAdvantages:")
for adv in response.advantages:
    print(f"- {adv}")

print("\nDisadvantages:")
for dis in response.disadvantages:
    print(f"- {dis}")

print(f"\nExam Tip:\n{response.exam_tip}")
# Out:
# Topic: Deadlock
#
# Definition:
# A deadlock is a situation in a multithreaded program where two or more threads are unable to proceed because each is waiting for the other to release a resource.
#
# Important Points:
# - Deadlock occurs when two or more threads are competing for shared resources.
# - Each thread is waiting for the other thread to release a resource.
# - Deadlock can occur in operating systems, databases, and other applications.
# - Deadlock can be avoided by using techniques such as locking ordering and deadlock detection.
# - Deadlock detection and recovery can be costly in terms of system resources and time.
#
# Advantages:
# - Deadlock detection can help prevent system crashes and data loss.
#
# Disadvantages:
# - Deadlock detection and recovery can be costly in terms of system resources and time.
# - Deadlock can cause system instability and performance issues.
#
# Exam Tip:
# ...
